# %% [markdown]
# 1. For running the program we need a software known as compiler or interpreter.
# 2. For writing the program we need  IDE.(Pycharm)

# %% [markdown]
# ### How it works
# - Code ===>IDE==>Interpret/Compiler==>Byte_code==>PVM==>output==>IDE
# - IDE(INTEGRATED DEVLOPMENT ENVIRONMENT)
# - PVM(PYTHON VIRTUAL MACHINES)

# %% [markdown]
# ## **Python**

# %%
'''Python is a General Purpose programming language.(Ex.Solving problem,Automate)
Python is a High level pro_language.
Developed by Gudio VAn Rossum in 1989, Working National Institute at Netherland.
But offically python was  launched in Feb 20 1991.
This is the first programming language for beginners.'''
# Out:
# 'Python is a General Purpose programming language.(Ex.Solving problem,Automate)\nPython is a High level pro_language.\nDeveloped by Gudio VAn Rossum in 1989, Working National Institute at Netherland.\nBut offically python was  launched in Feb 20 1991.\nThis is the first programming language for beginners.'

# %% [raw]
# #print hello in C
# #include<stdio.h>
# void main()
# {
#     printf("hello world");
# }

# %%
#Print Hellp World in Python

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
c=a+b
print(c)
# Out:
# 30

# %%
print("the sum of a and b is:",a+b)
# Out:
# the sum of a and b is: 30

# %%
#Overall python is easy

# %%
# Python is open_source.
# Anyone can modify the code of python.
# C+Python=CPython

# %% [markdown]
# ### ***How Gudio has written the python?***

# %% [markdown]
# ### ***Features of Python***
#  1. Python is Simple and Easy.
#  2. Freeware and Open Source.
#  3. High Level Programming Language.
#  4. Platform Independent.
#  5. Python is Portable(we can migrate from one platform to another platform).
#  6. Dynamically Typed Languague.
#  7. Procedure Oriented (like"C") and Object Oriented (like"C++").
#  8. Interpreted language.
#  9. Extensible langugae(with python you can use other programming language as well)
#  10. Embedded
#  11. Extensive library

# %% [markdown]
# ### ***Flavours of Python***
# - C + Python= CPython
# - C + Python=Cython
# - Java+Python=Jython
# -  Python+Python=PyPython
# -  Anaconda+Python=Anacondapython

# %% [markdown]
# ### ***Versions of python***
# - Python 1.0 V - Jan 1994
# - Python 2.0 V - Oct 2000
# - Python 3.0 V - Dec 2008
