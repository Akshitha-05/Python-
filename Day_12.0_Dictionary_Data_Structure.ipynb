# %% [markdown]
# ## Dictionary Data Structure
# Key : "value"

# %% [markdown]
# 1. key - unique
# 2. values can be duplicates

# %% [markdown]
# - if we need to represent the data in one as object other feature of object.
#     1. Insertion order doesnot preserve.
#     2. Duplicates are allowed.
#     3. It is mutable.
#     4. Dynamic in nature
#     5. Indexing and Slicing are not applicable

# %%
d={}
type(d)
# Out:
# dict

# %%
d=dict()
type(d)
# Out:
# dict

# %%
d[100]="anil"
d[200]='pavan'
d[300]='virat kohli'

# %%
d
# Out:
# {100: 'anil', 200: 'pavan', 300: 'virat kohli'}

# %%
d={"key":"pair"}

# %% [markdown]
# ### how to access data from dictionary

# %%
d={100:'abhi',200:'ishan',300:'tilak'}

# %%
d[100]
# Out:
# 'abhi'

# %%
d[200]
# Out:
# 'ishan'

# %%
d[400]='surya'
d
# Out:
# {100: 'abhi', 200: 'ishan', 300: 'tilak', 400: 'surya'}

# %%
d[300]='sanju'

# %%
d
# Out:
# {100: 'abhi', 200: 'ishan', 300: 'sanju', 400: 'surya'}

# %% [markdown]
# ### Delete elemnt from dictionary

# %%
d={100:'abhi',200:'ishan',300:'tilak'}

# %%
del d[200]
d
# Out:
# {100: 'abhi', 300: 'tilak'}

# %%
d.clear()
d
# Out:
# {}

# %%
del d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# ### important function of dictionary

# %%
#dict() --> is used to create dictionary
d=dict()

# %%
d=dict({100:'apple',200:'mango'})
d
# Out:
# {100: 'apple', 200: 'mango'}

# %%
#len() --> lenghth of dictionary
len(d)
# Out:
# 2

# %%
#get() -->it will get value of that key 
d=dict({100:'apple',200:'mango'})
d.get(100)
# Out:
# 'apple'

# %%
# to delete the element from dictionary -->pop()
d.pop(100)
# Out:
# 'apple'

# %%
d
# Out:
# {200: 'mango'}

# %%
d={'blue':'sky','sky':'skyblue'}

# %%
d.popitem()
# Out:
# ('sky', 'skyblue')

# %%
d
# Out:
# {'blue': 'sky'}

# %% [markdown]
# ### Return associated keys with each dictionary

# %%
d={1:'10th',2:'12th',3:'degree'}

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
for i in d.keys():
    print(i)
# Out:
# 1
# 2
# 3

# %%
d.values()
# Out:
# dict_values(['10th', '12th', 'degree'])

# %%
for i in d.values():
    print(i)
# Out:
# 10th
# 12th
# degree

# %%
d1=d.copy()
d1
# Out:
# {1: '10th', 2: '12th', 3: 'degree'}

# %%
## write a program to take dictionary as input from keyboard and get the values as output

# %%
d=eval(input('enter the dictionary'))
s=sum(d.values())
print(s)
# Out:
# enter the dictionary {'a':10,'b':20}
# 30

# %%
## write a program to take dictionary as input from keyboard and get the keys as output

# %%
d=eval(input('enter the dictionary'))
s=sum(d.keys())
print(s)
# Out:
# enter the dictionary {101:200,102:300}
# 203
