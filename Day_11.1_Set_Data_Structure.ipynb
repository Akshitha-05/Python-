# %% [markdown]
# ## Set Data Structure

# %% [markdown]
# - if we want to represent a group of unique elements then we should use set.
#     1. Duplicates are not allowed.
#     2. Insertion order is not preserved.
#     3. We can sort the element.
#     4. Indexing and slicing are not allowed.
#     5. Hetrogeneous pobjects are allowed.

# %%
s={10,30,40,50}
type(s)
# Out:
# set

# %%
s={10,10,10,10}
s
# Out:
# {10}

# %%
lst=[10,20,20,20,30,30,30]
s=set(lst)

# %%
s
# Out:
# {10, 20, 30}

# %%
five=set(range(5))
five
# Out:
# {0, 1, 2, 3, 4}

# %%
s={}
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s=set(s)
type(s)
# Out:
# set

# %% [markdown]
# ### Few functions of Set

# %%
# adding values  in set
s={10,20,30}

# %%
#adding one elements we use add
s.add(40)

# %%
s
# Out:
# {10, 20, 30, 40}

# %%
# adding multiple elements we use update fun

# %%
l=[50,60,70]

# %%
s.update(l)

# %%
s
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
#copy 
s={10,20,30,40}

# %%
s1=s.copy()
s1
# Out:
# {10, 20, 30, 40}

# %%
#pop and remove

# %%
s1.pop()
# Out:
# 40

# %%
s1
# Out:
# {10, 20, 30}

# %%
#remove ->specific elment remove fom set
s1.remove(20)

# %%
s1
# Out:
# {30}

# %%
#discard is used to escape the error

# %% [raw]
# s1.discard(10)

# %%
s1
# Out:
# {30}

# %%
## clear function -->to remove all the elements in the set

# %%
set1={1,2,3,4,5,6}

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.clear()

# %%
set1
# Out:
# set()

# %% [markdown]
# ### *mathematical opertors on set*

# %%
# Union()

# %%
s1={10,20,30}
s2={50,60,70,30}

# %%
s1.union(s2)
# Out:
# {10, 20, 30, 50, 60, 70}

# %%
s1|s2
# Out:
# {10, 20, 30, 50, 60, 70}

# %%
# intersection()

# %%
s1.intersection(s2)
# Out:
# {30}

# %%
s1&s2
# Out:
# {30}

# %%
# write a program to print different vowels present in given word

# %%
v={'a','e','i','o','u'}
s=input("enter the value")
s1=set(s)
v.intersection(s)
# Out:
# enter the value akshitha
# {'a', 'i'}

# %%
# write a program to remove duplicate from a list

# %%
l=input("enter the elements")
s=set(l)
s
# Out:
# enter the elements 1,2,3,4,5,6,7,5,6,6,5,4
# {',', '1', '2', '3', '4', '5', '6', '7'}
