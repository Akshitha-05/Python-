# %% [markdown]
# # Introduction To Jupyter

# %% [markdown]
# ### ***Type of Cells***
# 1. Code ------> Write The Code (Program)
# 2. Markdown ------> Headings with Format
# 3. Raw -------->Raw Text without Format

# %% [markdown]
# ### *Into To Jupyter*
# - Esc+M = Markdown
# - Esc+Y = Code
# - Esc+R = Raw

# %%
### How to Give Headings 
 # Heading 
 ## Heading
 ### Heading
 #### Heading 
 ##### Heading
 ###### Heading (Esc+M --->shift enter)
# (note : the heading font size will be gradually decreasing .)

# %% [markdown]
# - *Examples*:
#  # Heading
#  ## Heading
#  ### Heading
#  #### Heading
#  ##### Heading
#  ###### Heading

# %%
### How to write in bold format
# **Bold** (Esc+M --->shift enter)

# %% [markdown]
# **To write in bold format**

# %%
### How to write in Italic format
# *Italic* (Esc+M --->shift enter)

# %% [markdown]
#  *Italic*

# %%
### How to write in  Bold and Italic format
# ***Bold and Italic*** (Esc+M --->shift enter)

# %% [markdown]
# ***Bold and Italic***

# %%
### How to write Unordered List(bullet points)
# - list (Esc+M --->shift enter)

# %% [markdown]
# - Examples
# - First_Day
# - Second_Day
# - Third_Day

# %%
### How to write Ordered List
# 1. list (Esc+M --->shift enter)

# %% [markdown]
# 1. Examples
# 2. First_Day
# 3. Second_Day
# 4. Third_Day

# %% [raw]
# Esc+A --->adding the cell above
# Esc+B --->adding the cell below
# Esc+DD--->deleting the cell
