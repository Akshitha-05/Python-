# %% [markdown]
# # **String Data Structure**

# %% [raw]
# -- Character char(python 2)
# -- string str(python 3)

# %%
name="Akshitha"

# %%
name='akshitha'

# %%
# multilinear literals
name=''' Munnanuri 
akshitha'''

# %% [markdown]
# 1. How to access characters of a string.
#    - there are two methods
#      1. By using index
#      2. by using slicing operator

# %% [markdown]
# ### *1.By using indexing*

# %%
name="akshitha"

# %% [raw]
# # index number feed to [].

# %%
name[0]
# Out:
# 'a'

# %%
name[1]
# Out:
# 'k'

# %%
s="aadhya"

# %%
s[4]
# Out:
# 'y'

# %%
s[-3]
# Out:
# 'h'

# %% [markdown]
# ##  *2. By using slicing operator*

# %% [raw]
# name _of_variable[start:stop:step]

# %%
s="Learning python is very very easy!"

# %%
s[0:0]
# Out:
# ''

# %%
s[0:1]
# Out:
# 'L'

# %%
s[0:38]
# Out:
# 'Learning python is very very easy!'

# %%
s[0:8:2]
# Out:
# 'Lann'

# %%
s[::]
# Out:
# 'Learning python is very very easy!'

# %%
#reversing string

# %%
s[::-1]
# Out:
# '!ysae yrev yrev si nohtyp gninraeL'

# %% [markdown]
# ### Mathematical operators on string

# %% [raw]
# + operator for concatanation
# * operator fpr repeatation

# %%
print(name+name)
# Out:
# akshithaakshitha

# %%
print(name*2)
# Out:
# akshithaakshitha

# %% [markdown]
# ### *Functions in String*
# we use function for repeation

# %% [markdown]
# - len() --> The number of charcters present in the strings.

# %%
s="Sweta"

# %%
len(s)
# Out:
# 5

# %% [markdown]
# ### *checking membership*
# - we can check the characters are present in string

# %%
s="durga"

# %%
's' in s
# Out:
# False

# %%
'a' in s
# Out:
# True

# %%
'z' not in s
# Out:
# True

# %%
s=input('enter the main string')
subs=input('enter the sub string')
if subs in s:
    print(subs,":is found in ",s)
else:
    print(subs,":is  not found in ",s)
# Out:
# enter the main string membership
# enter the sub string ship
# ship :is found in  membership

# %% [markdown]
# ### *Comparing the string*

# %%
s1=input("enter 1st string")
s2=input("enter 2nd string")
if s1==s2:
    print("both strings are equal")
elif s1>s2:
    print("1st string is greater than 2nd string")
else:
    print("2nd string is greater than 1st string")
# Out:
# enter 1st string Akshitha
# enter 2nd string Akshitha
# both strings are equal

# %%
s1=input("enter 1st string")
s2=input("enter 2nd string")
if s1==s2:
    print("both strings are equal")
elif s1>s2:
    print("1st string is greater than 2nd string")
else:
    print("2nd string is greater than 1st string")
# Out:
# enter 1st string akshitha
# enter 2nd string akki
# 1st string is greater than 2nd string

# %%
s1=input("enter 1st string")
s2=input("enter 2nd string")
if s1==s2:
    print("both strings are equal")
elif s1>s2:
    print("1st string is greater than 2nd string")
else:
    print("2nd string is greater than 1st string")
# Out:
# enter 1st string akki
# enter 2nd string akshitha
# 2nd string is greater than 1st string

# %% [markdown]
# ### *Removing spaces from the string*

# %% [markdown]
# - There are three method to remove space
#     1. rstrip() ---> remove space right hand side
#     2. lstrip() ---> remove space left hand side
#     3. strip() ----> remove space from both sides

# %%
city=input("enter your city name")
scity=city.strip()
if scity=="Hyderabad":
    print("Hello Hyderabadi .... Adaab")
elif scity=="Chennai":
    print("Hello Madrasi ....Vankaam")
elif scity=="Bengaluru":
    print("Hello Subhodya")
else:
    print("enter valid city name")
# Out:
# enter your city name Hyderabad
# Hello Hyderabadi .... Adaab

# %% [markdown]
# ### *Finding Substring*

# %% [raw]
# * we can find out based on direction
# 1. Forward direction
#    find() - return first occurence of first substring.
#    index() - return the substring
# 2. Backward direction
#     rfind()
#     rindex()

# %%
s="Machine learning is learning machine"
s.find('machine')
# Out:
# 29

# %%
s.find("is")
# Out:
# 17

# %%
s.find('a',3,17)
# Out:
# 10

# %%
s="Machine learning is learning machine"
s.rfind('z')
# Out:
# -1

# %%
s.rfind('e')
# Out:
# 35

# %% [markdown]
# ##### By using index()

# %%
s.index("r",20,40)
# Out:
# 23

# %% [markdown]
# ### *Count Function*

# %%
#count
s="abcdabcdefghabcdefghabcadda"
s.count('a')
# Out:
# 6

# %%
s="abcdabcdefghabcdefghabcadda"
s.count('a',10,20)
# Out:
# 1

# %% [markdown]
# ### *Replacing the string with another string*

# %% [raw]
# variable.replace(oldstring,newstring)

# %%
s="Learning python is very hard!"
s.replace('hard','easy')
# Out:
# 'Learning python is very easy!'

# %% [markdown]
# ### *Splitting the string*

# %% [raw]
# variable.split(seperator)

# %%
t="tata counsulting"
t.split(sep=' ')
# Out:
# ['tata', 'counsulting']

# %%
s='learning java is little easy'
l=s.split()
for x in l:
    print(x)
# Out:
# learning
# java
# is
# little
# easy

# %%
d='20-02-2026'
today=d.split('-')
for x in today:
    print(x)
# Out:
# 20
# 02
# 2026

# %% [markdown]
# ### *Joining the string*

# %%
# seperator.join(group of strings)

# %%
t=('sunny','bunny','funny')
s=''.join(t)

# %%
s
# Out:
# 'sunnybunnyfunny'

# %%
t=('sunny','bunny','funny')
s='g-'.join(t)

# %%
s
# Out:
# 'sunnyg-bunnyg-funny'
