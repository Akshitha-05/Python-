# %% [markdown]
# ## Identifier
# - A name in Python Program is called Identifier.
# -  It can be the name of variable name,function name,module name or class name.

# %%
a=10

# %% [markdown]
# ## *Rules to define identifier in Python*

# %% [raw]
# 1. Only Alphabet symbols are allowed (Upper case and Lower case)
#    -->(# A-Z or a-z)
# 2. 0-9 digits are allowed.
# 3. (_) Underscore symbols are allowed.
# 4. $ symbol is not allowed.
#    #-->cash=20
#    #-->ca$h=20(syntax error)
# 5. Identifier should start with Character not with number.
#   #-->number=300
#   #-->number123=500
#   #-->1number=400(Syntax error)
# 6. Identifiers are case sensitive.
#    -->total=10
#    -->Total=20
#    -->TOTAL=30
# 7. We cannot use reserve words as identifiers.

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# private file and variable( _abc)
# Private file/Variable are of two types
# 1.Light private(_)
# 2.More private(_ _)
# both are used to internal help/support
